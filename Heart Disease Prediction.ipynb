# %% [markdown]
# # CONTEXT

# %% [raw]
# Heart disease is a term used to describe a range of conditions that affect the heart and blood vessels, such as coronary artery disease (CAD), heart attack, heart failure, and stroke. These conditions are among the leading causes of death and disability worldwide.
#
# Coronary artery disease (CAD) is a condition in which the coronary arteries (the blood vessels that supply blood to the heart muscle) become narrowed or blocked due to the accumulation of plaque (a mixture of fat, cholesterol, and other substances) on their inner walls. When the coronary arteries are narrowed or blocked, it can reduce the blood flow to the heart muscle, which can lead to chest pain (angina), heart attack, and other heart problems.
#
# High blood pressure (also known as hypertension) is a common risk factor for heart disease. It occurs when the blood vessels are consistently subjected to high pressure, which can damage the walls of the vessels and increase the risk of heart attack, stroke, and other health problems.

# %% [markdown]
# # FLUOROSCOPY AND THALLIUM STRESS TEST

# %% [raw]
# Fluoroscopy is a medical imaging technique that uses X-rays to produce real-time images of the inside of the body. It is often used to guide medical procedures, such as placing a catheter in a blood vessel or inserting a needle into the spine. Fluoroscopy can also be used to help diagnose certain medical conditions, such as abnormalities in the digestive system or blood vessels.
#
# In a fluoroscopy test of coronary heart disease, the number of coronary arteries (the blood vessels that supply blood to the heart muscle) that can be seen on the images may vary depending on the patient's individual anatomy and the severity of their coronary artery disease (CAD).
#
# Typically, the coronary arteries are divided into three main branches: the left main coronary artery, the left anterior descending artery, and the right coronary artery. In a normal heart, all three of these arteries should be visible on a fluoroscopy image. However, in a heart with CAD, one or more of these arteries may be partially or completely blocked, which can reduce the blood flow to the heart muscle.
#
# In general, the more severe the CAD, the fewer coronary arteries will be visible on the fluoroscopy images. For example, if a patient has CAD that affects all three of the main coronary arteries, it is likely that only one or two of the arteries will be visible on the images. On the other hand, if a patient has mild CAD that affects only one of the main coronary arteries, it is likely that all three of the arteries will be visible on the images.

# %% [markdown]
# # UNDERSTANDING THE DATA

# %% [raw]
# 1)age: age in years
# 2)sex: sex (1 = male; 0 = female)
# 3)cp: chest pain type
# -- Value 1: typical angina
# -- Value 2: atypical angina
# -- Value 3: non-anginal pain
# -- Value 4: asymptomatic
# 4)BP: Blood Pressure
# 5)chol: serum cholestoral in mg/dl
# 6)fbs: (fasting blood sugar > 120 mg/dl)
# -- Value 1:true
# -- Value 0:false)
# 7)restecg: resting electrocardiographic results
# -- Value 0: normal
# -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# -- Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
# 8)exang: exercise induced angina (1 = yes; 0 = no)
# 9)oldpeak = ST depression induced by exercise relative to rest
# 10)slope of ST: the slope of the peak exercise ST segment
# -- Value 1: upsloping
# -- Value 2: flat
# -- Value 3: downsloping
# 11)Number of vessels fluro :number of major vessels (0-3) colored by flourosopy
# 12)Thallium : results of Thallium test
# -- Value 3 = normal
# -- Value 6 = fixed defect(refers to an area of the heart muscle that is not getting enough blood flow (ischemia) and that does not improve with exercise. )
# -- Value 7 = reversable defect(less severe blockage of one or more coronary arteries, which is causing a temporary reduction in blood flow to the affected area of the heart muscle.)
# 13)Heart Diesease : target label
# -- Value 1: Presence
# -- Value 0: Absence
# 14)Max HR =  maximum heart rate achieved

# %% [markdown]
# # IMPORTING DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\lovel\Desktop\21 days of ml project\Heart_Disease_Prediction.csv")
data.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
print('The shape of the data is {}'.format(data.shape))
print('The cols are: {}'.format(data.columns))
# Out:
# The shape of the data is (270, 14)
# The cols are: Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %% [markdown]
# # Separating features and target

# %%
y = data['Heart Disease']
X = data.drop(columns = ['Heart Disease'], inplace = True)

# %%
y.head()
# Out:
# 0    Presence
# 1     Absence
# 2    Presence
# 3     Absence
# 4     Absence
# Name: Heart Disease, dtype: object

# %%
X = data
X.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium
# 0                        3         3
# 1                        0         7
# 2                        0         7
# ...

# %%
X.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
cols = list(X.columns)
cols
# Out:
# ['Age',
#  'Sex',
#  'Chest pain type',
#  'BP',
#  'Cholesterol',
#  'FBS over 120',
#  'EKG results',
#  'Max HR',
#  'Exercise angina',
#  'ST depression',
#  'Slope of ST',
#  'Number of vessels fluro',
#  'Thallium']

# %% [markdown]
# # DATA VISUALIZATION

# %%
req = X.join(y)
req.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
fig, axes = plt.subplots(5,3, figsize = (15,12))

for i,ax in enumerate(axes.flat):
    plt.figure(figsize = (10,10))
    ax.hist(data[data.columns[i]])
    
    ax.grid(True)
    ax.set_axisbelow
    ax.set_xticks([])
    ax.set_xlabel(cols[i])
    
    if i == 12:
        break
    
plt.show()

# %%
req.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %% [markdown]
# Here, even though every datatypes look numeric, some have been encoded as numbers. Such categorical but encoded columns are:
# Sex, Chest pain type, FBS over 120, EKG results, exercise angina and Heart Disease.

# %%
cols = list(req.columns)

# %%
cols
# Out:
# ['Age',
#  'Sex',
#  'Chest pain type',
#  'BP',
#  'Cholesterol',
#  'FBS over 120',
#  'EKG results',
#  'Max HR',
#  'Exercise angina',
#  'ST depression',
#  'Slope of ST',
#  'Number of vessels fluro',
#  'Thallium',
#  'Heart Disease']

# %%
#separating categorical and numeric features

num_cols = ['Age','BP','Cholesterol','Max HR','ST depression']
cat_cols = ['Sex','Chest pain type','FBS over 120','EKG results','Exercise angina',
                       'Number of vessels fluro','Thallium','Slope of ST']

# %%
for cat,num in zip(cat_cols, num_cols):
    plt.figure(figsize=(5,5))
    sns.set_theme(style='whitegrid')
    sns.boxplot(x = req[cat],y = req[num] ,data = req, hue = 'Heart Disease' )
    plt.xlabel(cat)
    plt.ylabel(num)
plt.show()

# %% [markdown]
# Some of the features are missing while plotting like 'Number of vessels fluro','Thallium','Slope of ST'

# %%
miss_feat = ['Number of vessels fluro','Thallium','Slope of ST',]

# %%
for cat,num in zip(miss_feat, num_cols):
    plt.figure(figsize=(5,5))
    sns.set_theme(style='whitegrid')
    sns.boxplot(y = req[num],x = req[cat] ,data = req, hue = 'Heart Disease' )
    plt.xlabel(cat)
    plt.ylabel(num)
plt.show()

# %% [markdown]
# # Conclusion:

# %% [raw]
# From the plots, following factors influence the presence of heart disease in a patient:
# a) males are more likely to have heart disease with the increase in age
# b)type of chest pain and bp has great role
# c)exercise angina is present or not
# d)number of vessls seen in fluroscopy
# e)results of Thallium test

# %%
req['Heart Disease'].replace({'Presence': 1, 'Absence' : 0},inplace = True)
y = req['Heart Disease']

# %%
req.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# ...

# %% [markdown]
# # CORRELATION ANALYSIS

# %%
correlations = req.corr()

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(correlations, annot = True, annot_kws={'fontsize': 20})
plt.show()

# %% [markdown]
# # Conclusion:
# It shows that presence of heart disease in a patient is highly related to their : 1) results of Thalium Stress Test 2)Number of coronary arteries vessels seen during fluoroscopy, 3)presence of exercise angina,  4) Chest pain type, 5)ST depression slope in their reports . Likewise, it is less correlated with fasting blood sugar, cholesterol, EKG results
# Some of them can also be found in the conclusions of Visualisation.

# %% [markdown]
# # INPUT THAT WE ASK FOR USER BASED ON FEATURE IMPORTANCE

# %% [raw]
# PRESENCE OF EXERCISE ANGINA
# RESULTS OF THALIUM STRESS TEST
# NUMBER OF CORONARY ARTERISE SEEN IN FLUOROSCOPY TEST
# CHEST PAIN TYPE
# SEX
# AGE
#
# FEATURES TO BE DROPPED FOR

# %%
X.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium
# 0                        3         3
# 1                        0         7
# 2                        0         7
# ...

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Heart Disease, dtype: int64

# %% [markdown]
# # CREATING TRAIN AND TEST DATA

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=0)

# %%
print('Shape of training data : {}'.format(X_train.shape))
print('Shape of test data: {}'.format(X_test.shape))
# Out:
# Shape of training data : (216, 13)
# Shape of test data: (54, 13)

# %% [markdown]
# # CREATING PIPELINE

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.ensemble import VotingClassifier

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
pipeline = Pipeline([
    ('scaler', RobustScaler()),
     ('vc', VotingClassifier([
        ('lr', LogisticRegression()),
        ('rf', RandomForestClassifier()),
        ('gb', GradientBoostingClassifier()),
         ('xboost', XGBClassifier())
    ]))
])

# %%
pipeline
# Out:
# Pipeline(steps=[('scaler', RobustScaler()),
#                 ('vc',
#                  VotingClassifier(estimators=[('lr', LogisticRegression()),
#                                               ('rf', RandomForestClassifier()),
#                                               ('gb',
#                                                GradientBoostingClassifier()),
#                                               ('xboost',
#                                                XGBClassifier(base_score=None,
#                                                              booster=None,
#                                                              callbacks=None,
#                                                              colsample_bylevel=None,
#                                                              colsample_bynode=None,
#                                                              colsample_bytree=None,
# ...

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', RobustScaler()),
#                 ('vc',
#                  VotingClassifier(estimators=[('lr', LogisticRegression()),
#                                               ('rf', RandomForestClassifier()),
#                                               ('gb',
#                                                GradientBoostingClassifier()),
#                                               ('xboost',
#                                                XGBClassifier(base_score=None,
#                                                              booster=None,
#                                                              callbacks=None,
#                                                              colsample_bylevel=None,
#                                                              colsample_bynode=None,
#                                                              colsample_bytree=None,
# ...

# %%
score = pipeline.score(X_test, y_test)
print(f'Test score: {score:.2f}')
# Out:
# Test score: 0.76

# %%
# Get the estimators of the VotingClassifier
estimators = pipeline.named_steps['vc'].estimators
estimators
# Out:
# [('lr', LogisticRegression()),
#  ('rf', RandomForestClassifier()),
#  ('gb', GradientBoostingClassifier()),
#  ('xboost',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=None, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 predictor=None, random_state=None, ...))]

# %%
# Use cross-validation to evaluate the performance of each estimator
for name, estimator in estimators:
    scores = cross_val_score(estimator, X, y, cv=5)
    print(f'{name} scores: {scores}')
    print(f'{name} mean score: {scores.mean():.2f}')
# Out:
# C:\Users\lovel\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\lovel\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# #  So, the logistic regression performed better than any other algorithm with mean score of 85%

# %%
set_config(display='diagram')

# %%
pipe  =  Pipeline([
    ('scaler', RobustScaler()),
    ('lr',LogisticRegression())
])

# %%
pipe
# Out:
# Pipeline(steps=[('scaler', RobustScaler()), ('lr', LogisticRegression())])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', RobustScaler()), ('lr', LogisticRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
y_pred[0]
# Out:
# 0

# %%
y_prob = pipe.predict_proba(X_test)

# %%
y_prob[0]
# Out:
# array([0.7088071, 0.2911929])
